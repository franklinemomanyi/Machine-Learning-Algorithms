# %% [markdown]
# <a href="https://colab.research.google.com/github/franklinemomanyi/machinelearning/blob/main/4_Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Position_Salaries.csv')
x = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
pr = LinearRegression()
lr = LinearRegression()

# %%
#Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=4)
xpoly = pf.fit_transform(x_train)
pr.fit(xpoly,y_train)
#Plot Diagram
plt.scatter(x_train, y_train, color='red')
plt.scatter(x_test, y_test, color='green')
plt.plot(x, pr.predict(pf.fit_transform(x)))
plt.title('Polynomial Regression')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %%
#Linear Regression
lr.fit(x_train,y_train)
#Plot diagram
plt.scatter(x_train, y_train, color='red')
plt.scatter(x_test, y_test, color='green')
plt.plot(x, lr.predict(x))
plt.title('Linear Regression')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.metrics import r2_score
lrpred = lr.predict(x_test)
prpred = pr.predict(pf.fit_transform(x_test))
lrscore = r2_score(y_test,lrpred)
prscore = r2_score(y_test,prpred)
print('Linear Regression: '+str(lrscore*100)+' %')
print('Polynomial Regression: '+str(prscore*100)+' %')
# Out:
# Linear Regression: 85.88877328994488 %
# Polynomial Regression: 97.55392877150003 %
